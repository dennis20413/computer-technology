# %% [markdown]
# <a href="https://colab.research.google.com/github/dennis20413/computer-technology/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🏗️ Lab 1: HTML Profile Card
from IPython.display import HTML, display
profile = HTML('''
<div style="font-family: Arial; max-width: 400px; border: 1px solid #ddd; border-radius: 12px; padding: 20px; text-align: center;">
  <img src="https://zh.wikipedia.org/zh-tw/%E9%BA%BB%E7%9C%81%E7%90%86%E5%B7%A5%E5%AD%A6%E9%99%A2>" width="80" style="border-radius: 50%;">
  <h2 style="margin: 10px 0 5px;">MIT Student</h2>
  <p style="color: #888; font-size: 14px;">Data Science | Class of 2026</p>
  <div style="display: flex; justify-content: space-around; margin: 15px 0; border-top: 1px solid #eee; padding-top: 15px;">
    <div><b>42</b><br><span style="color:#888;font-size:12px;">Posts </span></div>
    <div><b>1,234</b><br><span style="color:#888;font-size:12px;">Followers </span></div>
    <div><b>567</b><br><span style="color:#888;font-size:12px;">Following </span></div>
  </div>
  <button style="background: linear-gradient(45deg, #f09433, #e6683c, #dc2743, #cc2366, #bc1888); color: white; border: none; padding: 8px 30px; border-radius: 6px; cursor: pointer; font-size: 14px;">Follow </button>
</div>
''')
display(profile)
print("💡 This entire card is HTML+CSS！")
print("   <div> = container  | <h2> = heading | <p> = paragraph ")
# ... (1 more lines)
# Out:
# <div style="font-family: Arial; max-width: 400px; border: 1px solid #ddd; border-radius: 12px; padding: 20px; text-align: center;">
#   <img src="https://zh.wikipedia.org/zh-tw/%E9%BA%BB%E7%9C%81%E7%90%86%E5%B7%A5%E5%AD%A6%E9%99%A2>" width="80" style="border-radius: 50%;">
#   <h2 style="margin: 10px 0 5px;">MIT Student</h2>
#   <p style="color: #888; font-size: 14px;">Data Science | Class of 2026</p>
#   <div style="display: flex; justify-content: space-around; margin: 15px 0; border-top: 1px solid #eee; padding-top: 15px;">
#     <div><b>42</b><br><span style="color:#888;font-size:12px;">Posts </span></div>
#     <div><b>1,234</b><br><span style="color:#888;font-size:12px;">Followers </span></div>
#     <div><b>567</b><br><span style="color:#888;font-size:12px;">Following </span></div>
#   </div>
# ...

# %%
# 🎨 Lab 2: CSS Brand Gradient Generator
from IPython.display import HTML, display
brands = [
    ("Instagram", "linear-gradient(45deg, #f09433, #e6683c, #dc2743, #cc2366, #bc1888)"),
    ("Facebook", "linear-gradient(to right, #1877F2, #0D6EFD)"),
    ("LINE", "linear-gradient(to right, #06C755, #00B900)"),
    ("TikTok", "linear-gradient(to right, #000000, #25F4EE, #FE2C55)"),
    ("YouTube", "linear-gradient(to right, #FF0000, #CC0000)"),
]
html = '<div style="font-family:Arial;">'
for name, grad in brands:
    html += f'''<div style="background:{grad}; color:white; padding:15px 20px;
    border-radius:8px; margin:8px 0; font-weight:bold; font-size:16px;
    text-shadow: 1px 1px 2px rgba(0,0,0,0.3);">{name}</div>'''
html += '</div>'
display(HTML(html))
print("💡 CSS gradient syntax: linear-gradient(direction, color1, color2, ...)")
print("   漸層語法: linear-gradient(方向, 顏色1, 顏色2, ...)")
# ... (1 more lines)
# Out:
# <div style="font-family:Arial;"><div style="background:linear-gradient(45deg, #f09433, #e6683c, #dc2743, #cc2366, #bc1888); color:white; padding:15px 20px;
#     border-radius:8px; margin:8px 0; font-weight:bold; font-size:16px;
#     text-shadow: 1px 1px 2px rgba(0,0,0,0.3);">Instagram</div><div style="background:linear-gradient(to right, #1877F2, #0D6EFD); color:white; padding:15px 20px;
#     border-radius:8px; margin:8px 0; font-weight:bold; font-size:16px;
#     text-shadow: 1px 1px 2px rgba(0,0,0,0.3);">Facebook</div><div style="background:linear-gradient(to right, #06C755, #00B900); color:white; padding:15px 20px;
#     border-radius:8px; margin:8px 0; font-weight:bold; font-size:16px;
#     text-shadow: 1px 1px 2px rgba(0,0,0,0.3);">LINE</div><div style="background:linear-gradient(to right, #000000, #25F4EE, #FE2C55); color:white; padding:15px 20px;
#     border-radius:8px; margin:8px 0; font-weight:bold; font-size:16px;
# ...

# %%
# 📱 Lab 4: Responsive Design Simulator
from IPython.display import HTML, display
responsive = HTML('''
<div style="font-family: Arial;">
  <h3>📱 Responsive Design Demo 響應式設計展示</h3>
  <!-- Desktop view -->
  <div style="border:2px solid #333; border-radius:8px; padding:10px; margin:10px 0;">
    <div style="text-align:center; background:#333; color:white; padding:3px; font-size:11px;">Desktop 桌面版 (>768px)</div>
    <div style="display:flex; gap:10px; padding:10px;">
      <div style="flex:1; background:#E3F2FD; padding:15px; border-radius:6px;">Sidebar 側欄</div>
      <div style="flex:3; background:#FFF3E0; padding:15px; border-radius:6px;">Main Content 主內容</div>
      <div style="flex:1; background:#E8F5E9; padding:15px; border-radius:6px;">Ads 廣告</div>
    </div>
  </div>
  <!-- Mobile view -->
  <div style="border:2px solid #333; border-radius:8px; padding:10px; margin:10px 0; max-width:250px;">
    <div style="text-align:center; background:#333; color:white; padding:3px; font-size:11px;">Mobile 手機版 (<768px)</div>
    <div style="padding:10px;">
      <div style="background:#E3F2FD; padding:15px; border-radius:6px; margin-bottom:10px;">Sidebar 側欄</div>
      <div style="background:#FFF3E0; padding:15px; border-radius:6px; margin-bottom:10px;">Main Content 主內容</div>
      <div style="background:#E8F5E9; padding:15px; border-radius:6px;">Ads 廣告</div>
    </div>
  </div>
</div>
''')
display(responsive)
print("💡 Flexbox and Media Queries are key for responsive design!")
print("   Flexbox 和 Media Queries 是實現響應式設計的關鍵！")
# Out:
# <div style="font-family: Arial;">
#   <h3>📱 Responsive Design Demo 響應式設計展示</h3>
#   <!-- Desktop view -->
#   <div style="border:2px solid #333; border-radius:8px; padding:10px; margin:10px 0;">
#     <div style="text-align:center; background:#333; color:white; padding:3px; font-size:11px;">Desktop 桌面版 (>768px)</div>
#     <div style="display:flex; gap:10px; padding:10px;">
#       <div style="flex:1; background:#E3F2FD; padding:15px; border-radius:6px;">Sidebar 側欄</div>
#       <div style="flex:3; background:#FFF3E0; padding:15px; border-radius:6px;">Main Content 主內容</div>
#       <div style="flex:1; background:#E8F5E9; padding:15px; border-radius:6px;">Ads 廣告</div>
#     </div>
#   </div>
#   <!-- Mobile view -->
#   <div style="border:2px solid #333; border-radius:8px; padding:10px; margin:10px 0; max-width:250px;">
#     <div style="text-align:center; background:#333; color:white; padding:3px; font-size:11px;">Mobile 手機版 (<768px)</div>
#     <div style="padding:10px;">
# ...

# %%
# 📱 Lab 4: Responsive Design Simulator
from IPython.display import HTML, display
responsive = HTML('''
<div style="font-family: Arial;">
  <h3>📱 Responsive Design Demo 響應式設計展示</h3>
  <!-- Desktop view -->
  <div style="border:2px solid #333; border-radius:8px; padding:10px; margin:10px 0;">
    <div style="text-align:center; background:#333; color:white; padding:3px; font-size:11px;">Desktop 桌面版 (>768px)</div>
    <div style="display:flex; gap:10px; padding:10px;">
      <div style="flex:1; background:#E3F2FD; padding:15px; border-radius:6px;">Sidebar 側欄</div>
      <div style="flex:3; background:#FFF3E0; padding:15px; border-radius:6px;">Main Content 主內容</div>
      <div style="flex:1; background:#E8F5E9; padding:15px; border-radius:6px;">Ads 廣告</div>
    </div>
  </div>
  <!-- Mobile view -->
  <div style="border:2px solid #333; border-radius:8px; padding:10px; margin:10px 0; max-width:250px;">
    <div style="text-align:center; background:#333; color:white; padding:3px; font-size:11px;">Mobile 手機版 (<768px)</div>
    <div style="padding:10px;">
      <div style="background:#E3F2FD; padding:15px; border-radius:6px; margin-bottom:10px;">Sidebar 側欄</div>
      <div style="background:#FFF3E0; padding:15px; border-radius:6px; margin-bottom:10px;">Main Content 主內容</div>
      <div style="background:#E8F5E9; padding:15px; border-radius:6px;">Ads 廣告</div>
    </div>
  </div>
</div>
''')
display(responsive)
print("💡 Flexbox and Media Queries are key for responsive design!")
print("   Flexbox 和 Media Queries 是實現響應式設計的關鍵！")
# Out:
# <div style="font-family: Arial;">
#   <h3>📱 Responsive Design Demo 響應式設計展示</h3>
#   <!-- Desktop view -->
#   <div style="border:2px solid #333; border-radius:8px; padding:10px; margin:10px 0;">
#     <div style="text-align:center; background:#333; color:white; padding:3px; font-size:11px;">Desktop 桌面版 (>768px)</div>
#     <div style="display:flex; gap:10px; padding:10px;">
#       <div style="flex:1; background:#E3F2FD; padding:15px; border-radius:6px;">Sidebar 側欄</div>
#       <div style="flex:3; background:#FFF3E0; padding:15px; border-radius:6px;">Main Content 主內容</div>
#       <div style="flex:1; background:#E8F5E9; padding:15px; border-radius:6px;">Ads 廣告</div>
#     </div>
#   </div>
#   <!-- Mobile view -->
#   <div style="border:2px solid #333; border-radius:8px; padding:10px; margin:10px 0; max-width:250px;">
#     <div style="text-align:center; background:#333; color:white; padding:3px; font-size:11px;">Mobile 手機版 (<768px)</div>
#     <div style="padding:10px;">
# ...

# %%
# 💬 Lab 3: LINE Chat Bubble UI
from IPython.display import HTML, display
chat = HTML('''
<div style="font-family: Arial; max-width: 400px; background: #7ECBB4; padding: 15px; border-radius: 12px;">
  <div style="text-align:center; color:#fff; font-size:12px; margin-bottom:10px;">Today 今天 18:30</div>
  <!-- Friend's message (left) -->
  <div style="display:flex; margin:8px 0;">
    <div style="background:white; padding:10px 14px; border-radius:0 16px 16px 16px; max-width:70%; font-size:14px;">
      Hey! Are you coming to class? 嘿！你要來上課嗎？ 📚
    </div>
  </div>
  <!-- My message (right) -->
  <div style="display:flex; justify-content:flex-end; margin:8px 0;">
    <div style="background:#06C755; color:white; padding:10px 14px; border-radius:16px 0 16px 16px; max-width:70%; font-size:14px;">
      Yes! On my way 🏃 對！在路上了
    </div>
  </div>
  <!-- Friend's message -->
  <div style="display:flex; margin:8px 0;">
    <div style="background:white; padding:10px 14px; border-radius:0 16px 16px 16px; max-width:70%; font-size:14px;">
      Great! See you there. 太棒了！到時候見。 👋
    </div>
  </div>
  <div style="text-align:center; color:#fff; font-size:12px; margin-top:15px;">Delivered 已送達</div>
</div>
''')
display(chat)
print("💡 This is a basic chat UI! 這是一個基本的聊天室介面！")
print("   flexbox, border-radius, background, justify-content for layout.")
# Out:
# <div style="font-family: Arial; max-width: 400px; background: #7ECBB4; padding: 15px; border-radius: 12px;">
#   <div style="text-align:center; color:#fff; font-size:12px; margin-bottom:10px;">Today 今天 18:30</div>
#   <!-- Friend's message (left) -->
#   <div style="display:flex; margin:8px 0;">
#     <div style="background:white; padding:10px 14px; border-radius:0 16px 16px 16px; max-width:70%; font-size:14px;">
#       Hey! Are you coming to class? 嘿！你要來上課嗎？ 📚
#     </div>
#   </div>
#   <!-- My message (right) -->
#   <div style="display:flex; justify-content:flex-end; margin:8px 0;">
#     <div style="background:#06C755; color:white; padding:10px 14px; border-radius:16px 0 16px 16px; max-width:70%; font-size:14px;">
#       Yes! On my way 🏃 對！在路上了
#     </div>
#   </div>
#   <!-- Friend's message -->
#   <div style="display:flex; margin:8px 0;">
#     <div style="background:white; padding:10px 14px; border-radius:0 16px 16px 16px; max-width:70%; font-size:14px;">
# ...

# %%
# 🌙 Lab 5: Dark Mode with CSS Variables
from IPython.display import HTML, display
dark_demo = HTML('''
<div id="page" style="font-family:Arial; padding:20px; border-radius:12px; transition:all 0.3s;
     background:#ffffff; color:#333;">
  <h3>🌙 Dark Mode Demo 深色模式展示</h3>
  <p>CSS variables make theming easy! CSS 變數讓主題切換超簡單！</p>
  <div style="display:flex; gap:10px; margin:15px 0;">
    <div style="flex:1; padding:15px; background:#f0f0f0; border-radius:8px;">Card 1 卡片一</div>
    <div style="flex:1; padding:15px; background:#f0f0f0; border-radius:8px;">Card 2 卡片二</div>
  </div>
  <hr>
  <div style="display:flex; gap:10px; margin:15px 0;">
    <div style="flex:1; padding:15px; background:#1a1a2e; color:#e0e0e0; border-radius:8px;">Card 1 Dark 🌙</div>
    <div style="flex:1; padding:15px; background:#1a1a2e; color:#e0e0e0; border-radius:8px;">Card 2 Dark 🌙</div>
  </div>
</div>
''')
display(dark_demo)
print("💡 CSS variables are great for toggling themes like dark mode!")
print("   CSS 變數很適合用來切換主題，例如深色模式！")
# Out:
# <div id="page" style="font-family:Arial; padding:20px; border-radius:12px; transition:all 0.3s;
#      background:#ffffff; color:#333;">
#   <h3>🌙 Dark Mode Demo 深色模式展示</h3>
#   <p>CSS variables make theming easy! CSS 變數讓主題切換超簡單！</p>
#   <div style="display:flex; gap:10px; margin:15px 0;">
#     <div style="flex:1; padding:15px; background:#f0f0f0; border-radius:8px;">Card 1 卡片一</div>
#     <div style="flex:1; padding:15px; background:#f0f0f0; border-radius:8px;">Card 2 卡片二</div>
#   </div>
#   <hr>
#   <div style="display:flex; gap:10px; margin:15px 0;">
#     <div style="flex:1; padding:15px; background:#1a1a2e; color:#e0e0e0; border-radius:8px;">Card 1 Dark 🌙</div>
#     <div style="flex:1; padding:15px; background:#1a1a2e; color:#e0e0e0; border-radius:8px;">Card 2 Dark 🌙</div>
#   </div>
# </div>
# 💡 CSS variables are great for toggling themes like dark mode!
#    CSS 變數很適合用來切換主題，例如深色模式！

# %%
from IPython.display import HTML,display
display(HTML('''<div style="font-family:Arial;"><h3>📐 CSS Box Model</h3>
<div style="background:#FFE0B2;padding:5px;display:inline-block;margin:5px;">
<div style="background:#FFCC80;padding:5px;border:3px solid #F57C00;">
<div style="background:#FFB74D;padding:20px;border:3px dashed #E65100;">
<div style="background:#FF9800;padding:15px;color:white;font-weight:bold;">Content 內容</div>
</div><small>Padding 內距</small></div><small>Border 邊框</small></div><small>Margin 外距</small></div>'''))
print("💡 Box Model: margin → border → padding → content")
print("   Every element follows this pattern! 每個元素都遵循這個模式！")
# Out:
# <div style="font-family:Arial;"><h3>📐 CSS Box Model</h3>
# <div style="background:#FFE0B2;padding:5px;display:inline-block;margin:5px;">
# <div style="background:#FFCC80;padding:5px;border:3px solid #F57C00;">
# <div style="background:#FFB74D;padding:20px;border:3px dashed #E65100;">
# <div style="background:#FF9800;padding:15px;color:white;font-weight:bold;">Content 內容</div>
# </div><small>Padding 內距</small></div><small>Border 邊框</small></div><small>Margin 外距</small></div>
# 💡 Box Model: margin → border → padding → content
#    Every element follows this pattern! 每個元素都遵循這個模式！

# %%
from IPython.display import HTML,display
colors = ['#E91E63','#9C27B0','#3F51B5','#2196F3','#4CAF50','#FF9800']
items = ''.join(f'<div style="width:90px;height:90px;background:{c};margin:4px;border-radius:8px;display:flex;align-items:center;justify-content:center;color:#fff;font-weight:bold;">📸</div>' for c in colors)
display(HTML(f'<div style="font-family:Arial;"><h3>🔲 Flexbox Grid</h3><div style="display:flex;flex-wrap:wrap;max-width:300px;">{items}</div></div>'))
print("💡 display:flex + flex-wrap:wrap = responsive grid! 響應式網格！")
print("   IG uses this for photo grids! IG 用這個做照片格！")
# Out:
# <div style="font-family:Arial;"><h3>🔲 Flexbox Grid</h3><div style="display:flex;flex-wrap:wrap;max-width:300px;"><div style="width:90px;height:90px;background:#E91E63;margin:4px;border-radius:8px;display:flex;align-items:center;justify-content:center;color:#fff;font-weight:bold;">📸</div><div style="width:90px;height:90px;background:#9C27B0;margin:4px;border-radius:8px;display:flex;align-items:center;justify-content:center;color:#fff;font-weight:bold;">📸</div><div style="width:90px;height:90px;background:#3F51B5;margin:4px;border-radius:8px;display:flex;align-items:center;justify-content:center;color:#fff;font-weight:bold;">📸</div><div style="width:90px;height:90px;background:#2196F3;margin:4px;border-radius:8px;display:flex;align-items:center;justify-content:center;color:#fff;font-weight:bold;">📸</div><div style="width:90px;height:90px;background:#4CAF50;margin:4px;border-radius:8px;display:flex;align-items:center;justify-content:center;color:#fff;font-weight:bold;">📸</div><div style
# ...

# %%
from IPython.display import HTML,display
display(HTML('''<div style="font-family:Arial;max-width:350px;padding:25px;border-radius:12px;background:#f5f5f5;">
<h3 style="text-align:center;">🔐 Login 登入</h3>
<input type="text" placeholder="Email 電子郵件" style="width:90%;padding:10px;margin:8px 0;border:1px solid #ddd;border-radius:6px;">
<input type="password" placeholder="Password 密碼" style="width:90%;padding:10px;margin:8px 0;border:1px solid #ddd;border-radius:6px;">
<button style="width:96%;padding:12px;background:#4CAF50;color:white;border:none;border-radius:6px;font-size:16px;cursor:pointer;margin-top:8px;">Login 登入</button>
<p style="text-align:center;font-size:12px;color:#888;">Forgot password? 忘記密碼？</p></div>'''))
print("💡 <input type='password'> hides characters with dots! 用圓點隱藏字元！")
# Out:
# <div style="font-family:Arial;max-width:350px;padding:25px;border-radius:12px;background:#f5f5f5;">
# <h3 style="text-align:center;">🔐 Login 登入</h3>
# <input type="text" placeholder="Email 電子郵件" style="width:90%;padding:10px;margin:8px 0;border:1px solid #ddd;border-radius:6px;">
# <input type="password" placeholder="Password 密碼" style="width:90%;padding:10px;margin:8px 0;border:1px solid #ddd;border-radius:6px;">
# <button style="width:96%;padding:12px;background:#4CAF50;color:white;border:none;border-radius:6px;font-size:16px;cursor:pointer;margin-top:8px;">Login 登入</button>
# <p style="text-align:center;font-size:12px;color:#888;">Forgot password? 忘記密碼？</p></div>
# 💡 <input type='password'> hides characters with dots! 用圓點隱藏字元！

# %%
from IPython.display import HTML,display
display(HTML('''<style>@keyframes spin{from{transform:rotate(0deg)}to{transform:rotate(360deg)}}</style>
<div style="font-family:Arial;text-align:center;"><h3>🎭 CSS Animation</h3>
<div style="width:50px;height:50px;border:5px solid #E0E0E0;border-top:5px solid #2196F3;border-radius:50%;animation:spin 1s linear infinite;margin:20px auto;"></div>
<p>Loading... 載入中...</p></div>'''))
print("💡 @keyframes define animation steps. animation: spin 1s infinite;")
print("   Loading spinners are just rotating borders! 載入圈圈就是旋轉的邊框！")
# Out:
# <style>@keyframes spin{from{transform:rotate(0deg)}to{transform:rotate(360deg)}}</style>
# <div style="font-family:Arial;text-align:center;"><h3>🎭 CSS Animation</h3>
# <div style="width:50px;height:50px;border:5px solid #E0E0E0;border-top:5px solid #2196F3;border-radius:50%;animation:spin 1s linear infinite;margin:20px auto;"></div>
# <p>Loading... 載入中...</p></div>
# 💡 @keyframes define animation steps. animation: spin 1s infinite;
#    Loading spinners are just rotating borders! 載入圈圈就是旋轉的邊框！

# %%
from IPython.display import HTML,display
rows = [("Alice","95","A+","🏆"),("Bob","82","B+",""),("Cindy","91","A","⭐"),("David","78","B",""),("Eve","88","A-","⭐")]
trs = ''.join(f'<tr style="border-bottom:1px solid #eee;"><td style="padding:8px;">{n}</td><td style="padding:8px;text-align:center;">{s}</td><td style="padding:8px;text-align:center;">{g}</td><td>{e}</td></tr>' for n,s,g,e in rows)
display(HTML(f'''<div style="font-family:Arial;max-width:400px;"><h3>📊 Grade Table 成績表</h3>
<table style="width:100%;border-collapse:collapse;"><thead>
<tr style="background:#2196F3;color:white;"><th style="padding:10px;">Name 姓名</th><th style="padding:10px;">Score</th><th style="padding:10px;">Grade</th><th>🏆</th></tr>
</thead><tbody>{trs}</tbody></table></div>'''))
print("💡 <table> + CSS = professional data display! 專業資料展示！")
# Out:
# <div style="font-family:Arial;max-width:400px;"><h3>📊 Grade Table 成績表</h3>
# <table style="width:100%;border-collapse:collapse;"><thead>
# <tr style="background:#2196F3;color:white;"><th style="padding:10px;">Name 姓名</th><th style="padding:10px;">Score</th><th style="padding:10px;">Grade</th><th>🏆</th></tr>
# ...

# %%
from IPython.display import HTML,display
cards = [("#E91E63","Photo 📸","span 2"),("#9C27B0","Video 🎬",""),("#2196F3","Story 📖",""),("#4CAF50","Reel 🎬","span 2"),("#FF9800","Post 📝",""),("#607D8B","Link 🔗","")]
items = ''.join(f'<div style="background:{c};padding:20px;border-radius:8px;color:white;font-weight:bold;{"grid-column:"+s+";" if s else ""}">{t}</div>' for c,t,s in cards)
display(HTML(f'''<div style="font-family:Arial;"><h3>🎨 CSS Grid Gallery</h3>
<div style="display:grid;grid-template-columns:repeat(3,1fr);gap:8px;max-width:400px;">{items}</div></div>'''))
print("💡 CSS Grid = 2D layout (rows + columns). Flexbox = 1D (row OR column)")
# Out:
# <div style="font-family:Arial;"><h3>🎨 CSS Grid Gallery</h3>
# <div style="display:grid;grid-template-columns:repeat(3,1fr);gap:8px;max-width:400px;"><div style="background:#E91E63;padding:20px;border-radius:8px;color:white;font-weight:bold;grid-column:span 2;">Photo 📸</div><div style="background:#9C27B0;padding:20px;border-radius:8px;color:white;font-weight:bold;">Video 🎬</div><div style="background:#2196F3;padding:20px;border-radius:8px;color:white;font-weight:bold;">Story 📖</div><div style="background:#4CAF50;padding:20px;border-radius:8px;color:white;font-weight:bold;grid-column:span 2;">Reel 🎬</div><div style="background:#FF9800;padding:20px;border-radius:8px;color:white;font-weight:bold;">Post 📝</div><div style="background:#607D8B;padding:20px;border-radius:8px;color:white;font-weight:bold;">Link 🔗</div></div></div>
# 💡 CSS Grid = 2D layout (rows + columns). Flexbox = 1D (row OR column)

# %%
from IPython.display import HTML,display
display(HTML('''<div style="font-family:Arial;"><h3>📱 Responsive Breakpoints 響應式斷點</h3>
<div style="display:flex;gap:10px;flex-wrap:wrap;">
<div style="border:2px solid #333;border-radius:8px;width:120px;padding:8px;">
<div style="background:#333;color:white;font-size:10px;text-align:center;padding:2px;">Mobile<360px</div>
<div style="background:#E3F2FD;padding:8px;font-size:10px;">☰ Menu<br>Content<br>Footer</div></div>
<div style="border:2px solid #333;border-radius:8px;width:200px;padding:8px;">
<div style="background:#333;color:white;font-size:10px;text-align:center;padding:2px;">Tablet 768px</div>
<div style="display:flex;gap:4px;padding:4px;"><div style="background:#E3F2FD;padding:8px;flex:1;font-size:10px;">Side</div><div style="background:#FFF3E0;padding:8px;flex:2;font-size:10px;">Content</div></div></div>
<div style="border:2px solid #333;border-radius:8px;width:300px;padding:8px;">
<div style="background:#333;color:white;font-size:10px;text-align:center;padding:2px;">Desktop>1024px</div>
<div style="display:flex;gap:4px;padding:4px;"><div style="background:#E3F2FD;padding:8px;flex:1;font-size:10px;">Nav</div><div style="background:#FFF3E0;padding:8px;flex:3;font-size:10px;">Main</div><div style="background:#E8F5E9;padding:8px;flex:1;font-size:10px;">Ads</div></div></div>
</div></div>'''))
print("💡 @media(max-width:768px){} → apply styles only on small screens!")
# Out:
# <div style="font-family:Arial;"><h3>📱 Responsive Breakpoints 響應式斷點</h3>
# <div style="display:flex;gap:10px;flex-wrap:wrap;">
# <div style="border:2px solid #333;border-radius:8px;width:120px;padding:8px;">
# <div style="background:#333;color:white;font-size:10px;text-align:center;padding:2px;">Mobile<360px</div>
# <div style="background:#E3F2FD;padding:8px;font-size:10px;">☰ Menu<br>Content<br>Footer</div></div>
# <div style="border:2px solid #333;border-radius:8px;width:200px;padding:8px;">
# <div style="background:#333;color:white;font-size:10px;text-align:center;padding:2px;">Tablet 768px</div>
# <div style="display:flex;gap:4px;padding:4px;"><div style="background:#E3F2FD;padding:8px;flex:1;font-size:10px;">Side</div><div style="background:#FFF3E0;padding:8px;flex:2;font-size:10px;">Content</div></div></div>
# <div style="border:2px solid #333;border-radius:8px;width:300px;padding:8px;">
# ...

# %%
from IPython.display import HTML,display
emojis = ["🏔️","🌊","🌅","🏙️","🌸","🦉"]
items = ''.join(f"<div style=\"width:80px;height:80px;background:#f0f0f0;border-radius:8px;display:flex;align-items:center;justify-content:center;font-size:36px;transition:transform 0.3s;cursor:pointer;\" onmouseover=\"this.style.transform='scale(1.3)'\" onmouseout=\"this.style.transform='scale(1)'\">{e}</div>" for e in emojis)
display(HTML(f'<div style="font-family:Arial;"><h3>🖼️ Hover Gallery (try hovering!)</h3><div style="display:flex;gap:8px;flex-wrap:wrap;">{items}</div></div>'))
print("💡 transition: transform 0.3s → smooth animation on hover!")
print("   CSS transforms: scale, rotate, translate, skew")
# Out:
# <div style="font-family:Arial;"><h3>🖼️ Hover Gallery (try hovering!)</h3><div style="display:flex;gap:8px;flex-wrap:wrap;"><div style="width:80px;height:80px;background:#f0f0f0;border-radius:8px;display:flex;align-items:center;justify-content:center;font-size:36px;transition:transform 0.3s;cursor:pointer;" onmouseover="this.style.transform='scale(1.3)'" onmouseout="this.style.transform='scale(1)'">🏔️</div><div style="width:80px;height:80px;background:#f0f0f0;border-radius:8px;display:flex;align-items:center;justify-content:center;font-size:36px;transition:transform 0.3s;cursor:pointer;" onmouseover="this.style.transform='scale(1.3)'" onmouseout="this.style.transform='scale(1)'">🌊</div><div style="width:80px;height:80px;background:#f0f0f0;border-radius:8px;display:flex;align-items:center;justify-content:center;font-size:36px;transition:transform 0.3s;cursor:pointer;" onmouseover="this.style.transform='scale(1.3)'" onmouseout="this.style.transform='scale(1)'">🌅</div><div style="width:8
# ...

# %%
from IPython.display import HTML,display
display(HTML('''<div style="font-family:Arial;max-width:350px;"><h3>🎯 Semantic HTML 語義化</h3>
<div style="display:flex;gap:10px;">
<div><b>❌ Bad 不好</b><pre style="background:#FFCDD2;padding:10px;border-radius:6px;font-size:11px;">&lt;div class="header"&gt;
&lt;div class="nav"&gt;
&lt;div class="content"&gt;
&lt;div class="footer"&gt;</pre></div>
<div><b>✅ Good 好</b><pre style="background:#C8E6C9;padding:10px;border-radius:6px;font-size:11px;">&lt;header&gt;
&lt;nav&gt;
&lt;main&gt;
&lt;footer&gt;</pre></div></div></div>'''))
print("💡 Screen readers (for blind users) understand <nav> but not <div>!")
print("   Semantic HTML = accessible web 語義HTML = 無障礙網頁")
# Out:
# <div style="font-family:Arial;max-width:350px;"><h3>🎯 Semantic HTML 語義化</h3>
# <div style="display:flex;gap:10px;">
# <div><b>❌ Bad 不好</b><pre style="background:#FFCDD2;padding:10px;border-radius:6px;font-size:11px;">&lt;div class="header"&gt;
# &lt;div class="nav"&gt;
# &lt;div class="content"&gt;
# &lt;div class="footer"&gt;</pre></div>
# <div><b>✅ Good 好</b><pre style="background:#C8E6C9;padding:10px;border-radius:6px;font-size:11px;">&lt;header&gt;
# &lt;nav&gt;
# &lt;main&gt;
# &lt;footer&gt;</pre></div></div></div>
# 💡 Screen readers (for blind users) understand <nav> but not <div>!
#    Semantic HTML = accessible web 語義HTML = 無障礙網頁

# %%
from IPython.display import HTML,display
display(HTML('''<div style="font-family:Arial;"><h3>🎪 CSS Variables 變數</h3>
<div style="display:flex;gap:10px;">
<div style="--accent:#2196F3;background:var(--accent);color:white;padding:15px;border-radius:8px;">Theme Blue 藍色主題<br>--accent: #2196F3</div>
<div style="--accent:#E91E63;background:var(--accent);color:white;padding:15px;border-radius:8px;">Theme Pink 粉色主題<br>--accent: #E91E63</div>
<div style="--accent:#4CAF50;background:var(--accent);color:white;padding:15px;border-radius:8px;">Theme Green 綠色主題<br>--accent: #4CAF50</div>
</div></div>'''))
print("💡 :root { --primary: #2196F3; } → use var(--primary) everywhere!")
print("   Change the variable = change entire theme! 改變數=改主題！")
# Out:
# <div style="font-family:Arial;"><h3>🎪 CSS Variables 變數</h3>
# <div style="display:flex;gap:10px;">
# <div style="--accent:#2196F3;background:var(--accent);color:white;padding:15px;border-radius:8px;">Theme Blue 藍色主題<br>--accent: #2196F3</div>
# <div style="--accent:#E91E63;background:var(--accent);color:white;padding:15px;border-radius:8px;">Theme Pink 粉色主題<br>--accent: #E91E63</div>
# <div style="--accent:#4CAF50;background:var(--accent);color:white;padding:15px;border-radius:8px;">Theme Green 綠色主題<br>--accent: #4CAF50</div>
# </div></div>
# 💡 :root { --primary: #2196F3; } → use var(--primary) everywhere!
#    Change the variable = change entire theme! 改變數=改主題！

# %%
from IPython.display import HTML,display
transforms = [("rotate(15deg)","旋轉"),("scale(1.2)","放大"),("skewX(10deg)","傾斜"),("translateX(20px)","平移")]
items = ''.join(f'<div style="width:70px;height:70px;background:#2196F3;margin:15px;display:inline-flex;align-items:center;justify-content:center;color:white;font-size:11px;border-radius:6px;transform:{t};">{n}</div>' for t,n in transforms)
display(HTML(f'<div style="font-family:Arial;"><h3>📐 CSS Transforms</h3>{items}</div>'))
print("💡 transform: rotate(45deg) scale(1.5) translateX(50px);")
print("   Combine multiple transforms! 組合多個變形！")
# Out:
# <div style="font-family:Arial;"><h3>📐 CSS Transforms</h3><div style="width:70px;height:70px;background:#2196F3;margin:15px;display:inline-flex;align-items:center;justify-content:center;color:white;font-size:11px;border-radius:6px;transform:rotate(15deg);">旋轉</div><div style="width:70px;height:70px;background:#2196F3;margin:15px;display:inline-flex;align-items:center;justify-content:center;color:white;font-size:11px;border-radius:6px;transform:scale(1.2);">放大</div><div style="width:70px;height:70px;background:#2196F3;margin:15px;display:inline-flex;align-items:center;justify-content:center;color:white;font-size:11px;border-radius:6px;transform:skewX(10deg);">傾斜</div><div style="width:70px;height:70px;background:#2196F3;margin:15px;display:inline-flex;align-items:center;justify-content:center;color:white;font-size:11px;border-radius:6px;transform:translateX(20px);">平移</div></div>
# 💡 transform: rotate(45deg) scale(1.5) translateX(50px);
#    Combine multiple transforms! 組合多個變形！

# %%
from IPython.display import HTML,display
grads = [("linear-gradient(135deg,#667eea,#764ba2)","Linear 線性"),("radial-gradient(circle,#f093fb,#f5576c)","Radial 放射"),("conic-gradient(#fd4,#fd4 25%,#4df 25%,#4df 50%,#d4f 50%,#d4f 75%,#f4d 75%)","Conic 錐形")]
items = ''.join(f'<div style="width:120px;height:80px;background:{g};border-radius:8px;display:flex;align-items:center;justify-content:center;color:white;font-weight:bold;font-size:12px;margin:5px;text-shadow:1px 1px 2px rgba(0,0,0,0.5);">{n}</div>' for g,n in grads)
display(HTML(f'<div style="font-family:Arial;"><h3>🌈 CSS Gradients</h3><div style="display:flex;gap:5px;">{items}</div></div>'))
print("💡 cssgraident.io — design beautiful gradients visually!")
# Out:
# <div style="font-family:Arial;"><h3>🌈 CSS Gradients</h3><div style="display:flex;gap:5px;"><div style="width:120px;height:80px;background:linear-gradient(135deg,#667eea,#764ba2);border-radius:8px;display:flex;align-items:center;justify-content:center;color:white;font-weight:bold;font-size:12px;margin:5px;text-shadow:1px 1px 2px rgba(0,0,0,0.5);">Linear 線性</div><div style="width:120px;height:80px;background:radial-gradient(circle,#f093fb,#f5576c);border-radius:8px;display:flex;align-items:center;justify-content:center;color:white;font-weight:bold;font-size:12px;margin:5px;text-shadow:1px 1px 2px rgba(0,0,0,0.5);">Radial 放射</div><div style="width:120px;height:80px;background:conic-gradient(#fd4,#fd4 25%,#4df 25%,#4df 50%,#d4f 50%,#d4f 75%,#f4d 75%);border-radius:8px;display:flex;align-items:center;justify-content:center;color:white;font-weight:bold;font-size:12px;margin:5px;text-shadow:1px 1px 2px rgba(0,0,0,0.5);">Conic 錐形</div></div></div>
# ...

# %%
from IPython.display import HTML,display
display(HTML('''<link href="<https://fonts.googleapis.com/css2?family=Roboto&family=Playfair+Display&family=Fira+Code&display=swap>" rel="stylesheet">
<div style="max-width:400px;"><h3>🔤 Google Fonts</h3>
<p style="font-family:'Roboto';font-size:16px;">Roboto — Google's favorite (Android, Material) 最愛字體</p>
<p style="font-family:'Playfair Display';font-size:16px;">Playfair Display — Elegant serif 優雅襯線</p>
<p style="font-family:'Fira Code';font-size:16px;">Fira Code — Perfect for code 程式碼專用 → != ≠</p>
<p style="font-family:serif;font-size:16px;">Default Serif — Browser default 瀏覽器預設 😴</p></div>'''))
print("💡 fonts.google.com — browse 1500+ free fonts!")
# Out:
# <link href="<https://fonts.googleapis.com/css2?family=Roboto&family=Playfair+Display&family=Fira+Code&display=swap>" rel="stylesheet">
# <div style="max-width:400px;"><h3>🔤 Google Fonts</h3>
# <p style="font-family:'Roboto';font-size:16px;">Roboto — Google's favorite (Android, Material) 最愛字體</p>
# <p style="font-family:'Playfair Display';font-size:16px;">Playfair Display — Elegant serif 優雅襯線</p>
# <p style="font-family:'Fira Code';font-size:16px;">Fira Code — Perfect for code 程式碼專用 → != ≠</p>
# <p style="font-family:serif;font-size:16px;">Default Serif — Browser default 瀏覽器預設 😴</p></div>
# 💡 fonts.google.com — browse 1500+ free fonts!

# %%
from IPython.display import HTML,display
checks = [("Color contrast 色彩對比","Text readable on background? 文字在背景上可讀？","✅"),("Alt text 替代文字","Images have descriptions? 圖片有描述？","⚠️"),("Keyboard nav 鍵盤導航","Can use Tab to navigate? 能用Tab導航？","✅"),("Font size 字體大小","Minimum 16px? 最小16px？","✅"),("Screen reader 螢幕閱讀器","Semantic HTML used? 使用語義HTML？","❌")]
display(HTML(f'''<div style="font-family:Arial;max-width:400px;"><h3>♿ Accessibility Audit</h3>
<table style="width:100%;border-collapse:collapse;">{''.join(f"<tr style='border-bottom:1px solid #eee;'><td style='padding:8px;'>{n}</td><td style='padding:8px;font-size:12px;'>{d}</td><td>{s}</td></tr>" for n,d,s in checks)}</table></div>'''))
print("💡 WCAG 2.1 = Web Content Accessibility Guidelines")
print("   Score: 3/5 — needs improvement! 需要改進！")
# Out:
# <div style="font-family:Arial;max-width:400px;"><h3>♿ Accessibility Audit</h3>
# ...

# %%
from IPython.display import HTML,display
display(HTML('''<div style="font-family:Arial;max-width:380px;border-radius:16px;overflow:hidden;box-shadow:0 4px 20px rgba(0,0,0,0.15);">
<div style="background:#06C755;padding:12px 16px;display:flex;align-items:center;gap:10px;">
<span style="font-size:20px;">←</span><img src="<https://api.dicebear.com/7.x/initials/svg?seed=AI>" width="32" style="border-radius:50%;"><span style="color:white;font-weight:bold;">AI Assistant 🤖</span></div>
<div style="background:#7ECBB4;padding:12px;min-height:200px;">
<div style="text-align:center;font-size:11px;color:#fff;margin-bottom:8px;">Today 14:30</div>
<div style="display:flex;margin:6px 0;"><div style="background:#fff;padding:10px 14px;border-radius:0 16px 16px 16px;max-width:70%;font-size:13px;">Hello! How was your CS class? 嗨！計概課怎麼樣？</div></div>
<div style="display:flex;justify-content:flex-end;margin:6px 0;"><div style="background:#06C755;color:white;padding:10px 14px;border-radius:16px 0 16px 16px;max-width:70%;font-size:13px;">Amazing! I learned HTML+CSS 超棒！學了HTML+CSS 🎉</div></div>
<div style="display:flex;margin:6px 0;"><div style="background:#fff;padding:10px 14px;border-radius:0 16px 16px 16px;max-width:70%;font-size:13px;">Show me what you built! 給我看你做的！</div></div>
<div style="display:flex;justify-content:flex-end;margin:6px 0;"><div style="background:#06C755;color:white;padding:10px 14px;border-radius:16px 0 16px 16px;max-width:70%;font-size:13px;">This chat IS what I built! 這個聊天室就是我做的！😎</div></div></div>
<div style="background:#fff;padding:10px;display:flex;gap:8px;align-items:center;border-top:1px solid #eee;">
<span style="font-size:20px;">😊</span><input style="flex:1;padding:8px;border:1px solid #ddd;border-radius:20px;" placeholder="Message..."><span style="font-size:20px;color:#06C755;">➤</span></div></div>'''))
print("🏆 You just built a LINE clone with HTML+CSS! 你用 HTML+CSS 仿製了 LINE！")
print("   Skills used 使用技能: Flexbox, border-radius, gradients, colors, spacing")
# Out:
# <div style="font-family:Arial;max-width:380px;border-radius:16px;overflow:hidden;box-shadow:0 4px 20px rgba(0,0,0,0.15);">
# <div style="background:#06C755;padding:12px 16px;display:flex;align-items:center;gap:10px;">
# <span style="font-size:20px;">←</span><img src="<https://api.dicebear.com/7.x/initials/svg?seed=AI>" width="32" style="border-radius:50%;"><span style="color:white;font-weight:bold;">AI Assistant 🤖</span></div>
# <div style="background:#7ECBB4;padding:12px;min-height:200px;">
# <div style="text-align:center;font-size:11px;color:#fff;margin-bottom:8px;">Today 14:30</div>
# <div style="display:flex;margin:6px 0;"><div style="background:#fff;padding:10px 14px;border-radius:0 16px 16px 16px;max-width:70%;font-size:13px;">Hello! How was your CS class? 嗨！計概課怎麼樣？</div></div>
# ...
